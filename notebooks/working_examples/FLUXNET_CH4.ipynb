# %%
import pandas as pd
from datetime import datetime
import os
import zipfile
import re

# %%
def int_to_datetime(value: int) -> datetime:
    """
    TIMESTAMP_START/END -> YYYYMMDDhhmm  (INT)
    """
    chain = str(value)

    year = int(chain[:4])
    month = int(chain[4:6])
    day = int(chain[6:8])

    hour = int(chain[8:10])
    minute = int(chain[10:12])

    dt = datetime(year, month, day, hour, minute)
    return dt


# value = df["TIMESTAMP_START"][0]
# print(value)
# print(int_to_datetime(value))

# %% [markdown]
# # Download the data from fluxnet:
# #downloadDate:20240402012429
# #numberOfSitesDownloaded:35
# #emailforSitePIs:Andrew.Ouimette@usda.gov, Baldocchi@berkeley.edu, Sebastien.Gogo@univ-orleans.fr, baldocchi@berkeley.edu, bbergama@usgs.gov, brrunkle@uark.edu, desai@aos.wisc.edu, dyflai@cuhk.edu.hk, eeva-stiina.tuittila@uef.fi, enzo.magliulo@cnr.it, gerald.jurasinski@uni-rostock.de, harazono2009gl@gmail.com, hirano@env.agr.hokudai.ac.jp, hiwata@shinshu-u.ac.jp, janne.rinne@helsinki.fi, lwindham-myers@usgs.gov, mats.b.nilsson@slu.se, michele.reba@ars.usda.gov, miyabi-flux@muh.biglobe.ne.jp, ms-kang@ncam.kr, mstorn@lbl.gov, nina.buchmann@usys.ethz.ch, oliver.sonnentag@umontreal.ca, rcsullivan@anl.gov, rhinkle@ucf.edu, sniu@igsnrr.ac.cn, ted.Schuur@nau.edu, torsten.sachs@gfz-potsdam.de, varlagin@sevin.ru, yryu@snu.ac.kr
#
# # EXAMPLE OF DOWNLOAD LINK (for my account tegoan)
# https://ftp.fluxdata.org/.fluxnet_ch4_downloads_72418/META/FLX_AA-Flx_CH4-META_20201112135337801132.csv?=tegoan
# #dataFiles
# SITE_ID,filename,start_year,end_year,version,filetype,timestamp
# AA-Flx,FLX_AA-Flx_CH4-META_20201112135337801132.csv,,,20201112,META,202011121353
# CA-SCB,FLX_CA-SCB_FLUXNET-CH4_DD_2014-2017_1-1.csv,2014,2017,1-1,FLUX-MET,202009151632
# CA-SCB,FLX_CA-SCB_FLUXNET-CH4_HH_2014-2017_1-1.csv,2014,2017,1-1,FLUX-MET,202009151632
# CH-Dav,FLX_CH-Dav_FLUXNET-CH4_DD_2016-2017_1-1.csv,2016,2017,1-1,FLUX-MET,202009151632
# CH-Dav,FLX_CH-Dav_FLUXNET-CH4_HH_2016-2017_1-1.csv,2016,2017,1-1,FLUX-MET,202009151632
# CN-Hgu,FLX_CN-Hgu_FLUXNET-CH4_DD_2015-2017_1-1.csv,2015,2017,1-1,FLUX-MET,202009151632
# CN-Hgu,FLX_CN-Hgu_FLUXNET-CH4_HH_2015-2017_1-1.csv,2015,2017,1-1,FLUX-MET,202009151632
# DE-Dgw,FLX_DE-Dgw_FLUXNET-CH4_DD_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# DE-Dgw,FLX_DE-Dgw_FLUXNET-CH4_HH_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# DE-Hte,FLX_DE-Hte_FLUXNET-CH4_DD_2011-2018_1-1.csv,2011,2018,1-1,FLUX-MET,202009151632
# DE-Hte,FLX_DE-Hte_FLUXNET-CH4_HH_2011-2018_1-1.csv,2011,2018,1-1,FLUX-MET,202009151632
# DE-Zrk,FLX_DE-Zrk_FLUXNET-CH4_DD_2013-2018_1-1.csv,2013,2018,1-1,FLUX-MET,202009151632
# DE-Zrk,FLX_DE-Zrk_FLUXNET-CH4_HH_2013-2018_1-1.csv,2013,2018,1-1,FLUX-MET,202009151632
# FI-Sii,FLX_FI-Sii_FLUXNET-CH4_DD_2013-2018_1-1.csv,2013,2018,1-1,FLUX-MET,202009151632
# FI-Sii,FLX_FI-Sii_FLUXNET-CH4_HH_2013-2018_1-1.csv,2013,2018,1-1,FLUX-MET,202009151632
# FR-LGt,FLX_FR-LGt_FLUXNET-CH4_DD_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# FR-LGt,FLX_FR-LGt_FLUXNET-CH4_HH_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# HK-MPM,FLX_HK-MPM_FLUXNET-CH4_DD_2016-2018_1-1.csv,2016,2018,1-1,FLUX-MET,202009151632
# HK-MPM,FLX_HK-MPM_FLUXNET-CH4_HH_2016-2018_1-1.csv,2016,2018,1-1,FLUX-MET,202009151632
# ID-Pag,FLX_ID-Pag_FLUXNET-CH4_DD_2016-2017_1-1.csv,2016,2017,1-1,FLUX-MET,202009151632
# ID-Pag,FLX_ID-Pag_FLUXNET-CH4_HH_2016-2017_1-1.csv,2016,2017,1-1,FLUX-MET,202009151632
# IT-BCi,FLX_IT-BCi_FLUXNET-CH4_DD_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# IT-BCi,FLX_IT-BCi_FLUXNET-CH4_HH_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# JP-BBY,FLX_JP-BBY_FLUXNET-CH4_DD_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# JP-BBY,FLX_JP-BBY_FLUXNET-CH4_HH_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# KR-CRK,FLX_KR-CRK_FLUXNET-CH4_DD_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# KR-CRK,FLX_KR-CRK_FLUXNET-CH4_HH_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# RU-Fy2,FLX_RU-Fy2_FLUXNET-CH4_DD_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# RU-Fy2,FLX_RU-Fy2_FLUXNET-CH4_HH_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# SE-Deg,FLX_SE-Deg_FLUXNET-CH4_DD_2014-2018_1-1.csv,2014,2018,1-1,FLUX-MET,202009151632
# SE-Deg,FLX_SE-Deg_FLUXNET-CH4_HH_2014-2018_1-1.csv,2014,2018,1-1,FLUX-MET,202009151632
# US-A03,FLX_US-A03_FLUXNET-CH4_DD_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# US-A03,FLX_US-A03_FLUXNET-CH4_HH_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# US-A10,FLX_US-A10_FLUXNET-CH4_DD_2012-2018_1-1.csv,2012,2018,1-1,FLUX-MET,202009151632
# US-A10,FLX_US-A10_FLUXNET-CH4_HH_2012-2018_1-1.csv,2012,2018,1-1,FLUX-MET,202009151632
# US-Bi1,FLX_US-Bi1_FLUXNET-CH4_DD_2016-2018_1-1.csv,2016,2018,1-1,FLUX-MET,202009151632
# US-Bi1,FLX_US-Bi1_FLUXNET-CH4_HH_2016-2018_1-1.csv,2016,2018,1-1,FLUX-MET,202009151632
# US-Bi2,FLX_US-Bi2_FLUXNET-CH4_DD_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# US-Bi2,FLX_US-Bi2_FLUXNET-CH4_HH_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# US-DPW,FLX_US-DPW_FLUXNET-CH4_DD_2013-2017_1-1.csv,2013,2017,1-1,FLUX-MET,202009151632
# US-DPW,FLX_US-DPW_FLUXNET-CH4_HH_2013-2017_1-1.csv,2013,2017,1-1,FLUX-MET,202009151632
# US-EML,FLX_US-EML_FLUXNET-CH4_DD_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# US-EML,FLX_US-EML_FLUXNET-CH4_HH_2015-2018_1-1.csv,2015,2018,1-1,FLUX-MET,202009151632
# US-Ho1,FLX_US-Ho1_FLUXNET-CH4_DD_2012-2018_1-1.csv,2012,2018,1-1,FLUX-MET,202009151632
# US-Ho1,FLX_US-Ho1_FLUXNET-CH4_HH_2012-2018_1-1.csv,2012,2018,1-1,FLUX-MET,202009151632
# US-HRA,FLX_US-HRA_FLUXNET-CH4_DD_2017-2017_1-1.csv,2017,2017,1-1,FLUX-MET,202009151632
# US-HRA,FLX_US-HRA_FLUXNET-CH4_HH_2017-2017_1-1.csv,2017,2017,1-1,FLUX-MET,202009151632
# US-HRC,FLX_US-HRC_FLUXNET-CH4_DD_2017-2017_1-1.csv,2017,2017,1-1,FLUX-MET,202009151632
# US-HRC,FLX_US-HRC_FLUXNET-CH4_HH_2017-2017_1-1.csv,2017,2017,1-1,FLUX-MET,202009151632
# US-Los,FLX_US-Los_FLUXNET-CH4_DD_2014-2018_1-1.csv,2014,2018,1-1,FLUX-MET,202009151632
# US-Los,FLX_US-Los_FLUXNET-CH4_HH_2014-2018_1-1.csv,2014,2018,1-1,FLUX-MET,202009151632
# US-Myb,FLX_US-Myb_FLUXNET-CH4_DD_2010-2018_1-1.csv,2010,2018,1-1,FLUX-MET,202009151632
# US-Myb,FLX_US-Myb_FLUXNET-CH4_HH_2010-2018_1-1.csv,2010,2018,1-1,FLUX-MET,202009151632
# US-NGB,FLX_US-NGB_FLUXNET-CH4_DD_2012-2018_1-1.csv,2012,2018,1-1,FLUX-MET,202009151632
# US-NGB,FLX_US-NGB_FLUXNET-CH4_HH_2012-2018_1-1.csv,2012,2018,1-1,FLUX-MET,202009151632
# US-NGC,FLX_US-NGC_FLUXNET-CH4_DD_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# US-NGC,FLX_US-NGC_FLUXNET-CH4_HH_2017-2018_1-1.csv,2017,2018,1-1,FLUX-MET,202009151632
# US-PFa,FLX_US-Pfa_FLUXNET-CH4_DD_2010-2018_1-1.csv,2010,2018,1-1,FLUX-MET,202009151632
# US-PFa,FLX_US-Pfa_FLUXNET-CH4_HH_2010-2018_1-1.csv,2010,2018,1-1,FLUX-MET,202009151632
# US-Sne,FLX_US-Sne_FLUXNET-CH4_DD_2016-2018_1-1.csv,2016,2018,1-1,FLUX-MET,202009151632
# US-Sne,FLX_US-Sne_FLUXNET-CH4_HH_2016-2018_1-1.csv,2016,2018,1-1,FLUX-MET,202009151632
# US-Srr,FLX_US-Srr_FLUXNET-CH4_DD_2014-2017_1-1.csv,2014,2017,1-1,FLUX-MET,202009151632
# US-Srr,FLX_US-Srr_FLUXNET-CH4_HH_2014-2017_1-1.csv,2014,2017,1-1,FLUX-MET,202009151632
# US-Tw1,FLX_US-Tw1_FLUXNET-CH4_DD_2011-2018_1-1.csv,2011,2018,1-1,FLUX-MET,202009151632
# US-Tw1,FLX_US-Tw1_FLUXNET-CH4_HH_2011-2018_1-1.csv,2011,2018,1-1,FLUX-MET,202009151632
# US-Tw4,FLX_US-Tw4_FLUXNET-CH4_DD_2013-2018_1-1.csv,2013,2018,1-1,FLUX-MET,202009151632
# US-Tw4,FLX_US-Tw4_FLUXNET-CH4_HH_2013-2018_1-1.csv,2013,2018,1-1,FLUX-MET,202009151632
# US-Twt,FLX_US-Twt_FLUXNET-CH4_DD_2009-2017_1-1.csv,2009,2017,1-1,FLUX-MET,202009151632
# US-Twt,FLX_US-Twt_FLUXNET-CH4_HH_2009-2017_1-1.csv,2009,2017,1-1,FLUX-MET,202009151632
# US-Uaf,FLX_US-Uaf_FLUXNET-CH4_DD_2011-2018_1-1.csv,2011,2018,1-1,FLUX-MET,202009151632
# US-Uaf,FLX_US-Uaf_FLUXNET-CH4_HH_2011-2018_1-1.csv,2011,2018,1-1,FLUX-MET,202009151632

# %%
# Data processing --------------------------------

""" 
Extract all relevant variables for TS from the stations that have data for 2017.
"""
folder_path = r"../data/raw/FLUXNET_CH4_has_2017_data"

# Load metadata into a separated dataframe
meta_path = folder_path + "/FLX_AA-Flx_CH4-META_20201112135337801132.csv"
meta_df = pd.read_csv(meta_path, header=0)
meta_df
# Out:
#    SITE_ID                        SITE_NAME                   SITE_PERSONNEL  \
# 0   AT-Neu                         Neustift                  Georg Wohlfahrt
# 1   BR-Npw        Northern Pantanal Wetland                 George Vourlitis
# 2   BW-Gum                             Guma                   Carole Helfter
# 3   BW-Nxr                          Nxaraga                   Carole Helfter
# 4   CA-SCB                 Scotty Creek Bog  Oliver Sonnentag, Manuel Helbig
# ..     ...                              ...                              ...
# 76  US-Tw4       Twitchell East End Wetland                 Dennis Baldocchi
# 77  US-Tw5                East Pond Wetland                 Dennis Baldocchi
# 78  US-Twt                 Twitchell Island                 Dennis Baldocchi
# 79  US-Uaf  University of Alaska, Fairbanks                  Masahito Ueyama
# 80  US-WPT         Winous Point North Marsh          Jiquen Chen, Housen Chu
#
#      COUNTRY        LAT         LON SITE_CLASSIFICATION   UPLAND_CLASS IGBP  \
# 0    Austria  47.116670   11.317500              Upland  Alpine meadow  GRA
# 1     Brazil -16.498000  -56.412000               Swamp            NaN  WSA
# 2   Botswana -18.964722   22.371111               Swamp            NaN  WET
# 3   Botswana -19.548056   23.179167               Swamp            NaN  GRA
# 4     Canada  61.308900 -121.298400                 Bog            NaN  WET
# ..       ...        ...         ...                 ...            ...  ...
# 76       USA  38.102744 -121.641329               Marsh            NaN  WET
# 77       USA  38.107192 -121.642576               Marsh            NaN  WET
# 78       USA  38.108720 -121.653100                Rice            NaN  CRO
# 79       USA  64.866270 -147.855530                 Bog            NaN  ENF
# 80       USA  41.464639  -82.996157               Marsh            NaN  WET
#
#    KOPPEN  ... YEAR_START YEAR_END  UTC_OFFSET  \
# 0     Dfb  ...       2010     2012           1
# 1      Aw  ...       2013     2016          -4
# 2     Bsh  ...       2018     2018           2
# 3     Bsh  ...       2018     2018           2
# 4     Dfc  ...       2014     2017          -7
# ..    ...  ...        ...      ...         ...
# 76    Csa  ...       2013     2018          -8
# 77    Csa  ...       2018     2018          -8
# 78    Csa  ...       2009     2017          -8
# 79    Dwc  ...       2011     2018          -9
# 80    Dfa  ...       2011     2013          -5
#
#                                SOIL_TEMP_PROBE_DEPTHS  MOSS_BROWN  \
# 0       TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm;           0
# 1                                                 NaN           0
# 2                                                 NaN           0
# 3                                                 NaN           0
# 4   TS_1 = 0cm; TS_2 = -0.02cm; TS_3 = -0.04cm; TS...           0
# ..                                                ...         ...
# 76  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 77  TS_1 = -0.02cm; TS_2 = -0.1cm; TS_3 = -0.02cm;...           0
# 78  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 79  TS_1 = -0.09cm; TS_2 = -0.183cm; TS_3 = -0.283...           1
# 80                      TS_1 = -0.1cm; TS_2 = -0.3cm;           0
#
#    MOSS_SPHAGNUM  AERENCHYMATOUS  ERI_SHRUB  TREE         DOM_VEG
# 0              0               1          0     0  aerenchymatous
# 1              0               1          0     1            tree
# 2              0               1          0     1  aerenchymatous
# 3              0               1          0     1  aerenchymatous
# 4              1               1          1     0   moss_sphagnum
# ..           ...             ...        ...   ...             ...
# 76             0               1          0     0  aerenchymatous
# 77             0               1          0     0  aerenchymatous
# 78             0               1          0     0  aerenchymatous
# 79             1               1          1     1   moss_sphagnum
# 80             0               1          0     0  aerenchymatous
#
# [81 rows x 22 columns]

# %%
# Files are compressed in a  zip that has a folder and two .csv, one for half hour measures and other for daily, we want HH data.

""" 
Open the folder, list every zip file in it

save the name of the station

'FLX_<name>_FLUXNET[...].zip'

Open only the .csv file with _HH_ in the name, load it into a dataframe and select the data.

Finally, append it to a list of dataframes

"""

# %%
import re
import zipfile
import pandas as pd

df_list = {}


def int_to_datetime(value: int) -> datetime:
    """
    TIMESTAMP_START/END -> YYYYMMDDhhmm  (INT)
    """
    chain = str(value)

    year = int(chain[:4])
    month = int(chain[4:6])
    day = int(chain[6:8])

    hour = int(chain[8:10])
    minute = int(chain[10:12])

    dt = datetime(year, month, day, hour, minute)
    return dt


def processing_df(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()

    # Select fot the relevant data:
    cols_to_keep = [
        "TIMESTAMP_START",
        "TIMESTAMP_END",
        "TS_1",
        "TS_2",
        "TS_3",
        "TS_4",
        "TS_5",
        "TS_6",
        "TS_7",
        "TS_8",
        # METADATA: SOIL_TEMP_PROBE_DEPTHS: Installed depth of soil temperature probe (cm, negative values indicate below the surface)
        "WTD",
        "TA",
    ]
    # Check for the variable before selecting it
    df = df[[col for col in cols_to_keep if col in df.columns]]

    # Turn timestamps into datetime,
    df.loc[:, "DATETIME_START"] = df.loc[:, "TIMESTAMP_START"].apply(
        lambda x: int_to_datetime(x)
    )
    df.loc[:, "DATETIME_END"] = df.loc[:, "TIMESTAMP_END"].apply(
        lambda x: int_to_datetime(x)
    )

    df.drop(columns=["TIMESTAMP_START", "TIMESTAMP_END"])

    # Filter the data to contain only 2017 datapoints
    start_date = datetime(2017, 1, 1)
    end_date = datetime(2017, 12, 31, 23, 59, 59)

    filter = df.loc[:, "DATETIME_START"].apply(lambda x: start_date <= x <= end_date)
    df = df.loc[filter, :]

    return df


def process_zip_file(zip_file_path):
    with zipfile.ZipFile(zip_file_path) as zip_file:
        for file_info in zip_file.infolist():

            if file_info.filename.endswith(".csv") and re.findall(
                "_HH_", file_info.filename
            ):
                # Save the name of the station:
                station = re.findall("FLX_(.{2}-.{3})_", file_info.filename)[0]

                with zip_file.open(file_info.filename) as csv_file:
                    df = pd.read_csv(csv_file)

                    # Process the data further:
                    df = processing_df(df)

                    # Add to the dictionary
                    df_list[station] = df


def process_files_in_folder(folder_path):
    for filename in os.listdir(folder_path):

        if filename.endswith(".zip"):
            print("Processing:", filename)

            zip_file_path = os.path.join(folder_path, filename)
            process_zip_file(zip_file_path)

# %%
folder_path = r"../data/raw/FLUXNET_CH4_has_2017_data"
process_files_in_folder(folder_path)
# Out:
# Processing: FLX_CA-SCB_FLUXNET-CH4_2014-2017_1-1.zip
# Processing: FLX_CH-Dav_FLUXNET-CH4_2016-2017_1-1.zip
# Processing: FLX_CN-Hgu_FLUXNET-CH4_2015-2017_1-1.zip
# Processing: FLX_DE-Dgw_FLUXNET-CH4_2015-2018_1-1.zip
# Processing: FLX_DE-Hte_FLUXNET-CH4_2011-2018_1-1.zip
# Processing: FLX_DE-Zrk_FLUXNET-CH4_2013-2018_1-1.zip
# Processing: FLX_FI-Sii_FLUXNET-CH4_2013-2018_1-1.zip
# Processing: FLX_FR-LGt_FLUXNET-CH4_2017-2018_1-1.zip
# Processing: FLX_HK-MPM_FLUXNET-CH4_2016-2018_1-1.zip
# Processing: FLX_ID-Pag_FLUXNET-CH4_2016-2017_1-1.zip
# Processing: FLX_IT-BCi_FLUXNET-CH4_2017-2018_1-1.zip
# Processing: FLX_JP-BBY_FLUXNET-CH4_2015-2018_1-1.zip
# Processing: FLX_KR-CRK_FLUXNET-CH4_2015-2018_1-1.zip
# Processing: FLX_RU-Fy2_FLUXNET-CH4_2015-2018_1-1.zip
# Processing: FLX_SE-Deg_FLUXNET-CH4_2014-2018_1-1.zip
# Processing: FLX_US-A03_FLUXNET-CH4_2015-2018_1-1.zip
# Processing: FLX_US-A10_FLUXNET-CH4_2012-2018_1-1.zip
# Processing: FLX_US-Bi1_FLUXNET-CH4_2016-2018_1-1.zip
# Processing: FLX_US-Bi2_FLUXNET-CH4_2017-2018_1-1.zip
# Processing: FLX_US-DPW_FLUXNET-CH4_2013-2017_1-1.zip
# Processing: FLX_US-EML_FLUXNET-CH4_2015-2018_1-1.zip
# Processing: FLX_US-Ho1_FLUXNET-CH4_2012-2018_1-1.zip
# Processing: FLX_US-HRA_FLUXNET-CH4_2017-2017_1-1.zip
# Processing: FLX_US-HRC_FLUXNET-CH4_2017-2017_1-1.zip
# Processing: FLX_US-Los_FLUXNET-CH4_2014-2018_1-1.zip
# Processing: FLX_US-Myb_FLUXNET-CH4_2010-2018_1-1.zip
# Processing: FLX_US-NGB_FLUXNET-CH4_2012-2018_1-1.zip
# Processing: FLX_US-NGC_FLUXNET-CH4_2017-2018_1-1.zip
# Processing: FLX_US-PFa_FLUXNET-CH4_2010-2018_1-1.zip
# Processing: FLX_US-Sne_FLUXNET-CH4_2016-2018_1-1.zip
# Processing: FLX_US-Srr_FLUXNET-CH4_2014-2017_1-1.zip
# Processing: FLX_US-Tw1_FLUXNET-CH4_2011-2018_1-1.zip
# Processing: FLX_US-Tw4_FLUXNET-CH4_2013-2018_1-1.zip
# Processing: FLX_US-Twt_FLUXNET-CH4_2009-2017_1-1.zip
# Processing: FLX_US-Uaf_FLUXNET-CH4_2011-2018_1-1.zip

# %%
station = [k for k in df_list.keys()][1]
print(station)
df = df_list[station]
import numpy as np

# replace missing values with nans
df.replace(-9999.0, np.nan, inplace=True)
df
# Out:
# CH-Dav
#        TIMESTAMP_START  TIMESTAMP_END      TS_1     TS_2      TS_3     TS_4  \
# 17569     201701010000   201701010030 -1.140300 -0.60167  0.003667  0.60833
# 17570     201701010030   201701010100 -1.158700 -0.60167  0.003333  0.60833
# 17571     201701010100   201701010130 -1.170300 -0.60000  0.005667  0.61000
# 17572     201701010130   201701010200 -1.207700 -0.60033  0.005000  0.61000
# 17573     201701010200   201701010230 -1.211000 -0.62133  0.006000  0.61100
# ...                ...            ...       ...      ...       ...      ...
# 35083     201712312100   201712312130 -0.054333  0.30033  0.742000  1.15500
# 35084     201712312130   201712312200 -0.055667  0.30000  0.742000  1.15500
# 35085     201712312200   201712312230 -0.054667  0.30000  0.743670  1.15500
# 35086     201712312230   201712312300 -0.055667  0.30000  0.742670  1.15500
# 35087     201712312300   201712312330 -0.053333  0.30000  0.742000  1.15500
#
#           TS_5    TS_6        TA      DATETIME_START        DATETIME_END
# 17569  1.65967  2.3177 -1.666670 2017-01-01 00:00:00 2017-01-01 00:30:00
# 17570  1.65400  2.3177 -1.866670 2017-01-01 00:30:00 2017-01-01 01:00:00
# 17571  1.64267  2.3197 -1.666670 2017-01-01 01:00:00 2017-01-01 01:30:00
# 17572  1.63967  2.3190 -2.066670 2017-01-01 01:30:00 2017-01-01 02:00:00
# 17573  1.63600  2.3200 -2.133330 2017-01-01 02:00:00 2017-01-01 02:30:00
# ...        ...     ...       ...                 ...                 ...
# 35083  1.90933  2.4390 -0.200000 2017-12-31 21:00:00 2017-12-31 21:30:00
# 35084  1.90900  2.4340 -0.066667 2017-12-31 21:30:00 2017-12-31 22:00:00
# 35085  1.90900  2.4283 -0.833333 2017-12-31 22:00:00 2017-12-31 22:30:00
# 35086  1.90900  2.4240 -0.666667 2017-12-31 22:30:00 2017-12-31 23:00:00
# 35087  1.90900  2.4250 -0.733333 2017-12-31 23:00:00 2017-12-31 23:30:00
#
# [17519 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, figsize=(15, 6))
ax.plot(df["DATETIME_START"], df["TS_1"])
# ax.plot(df["DATETIME_START"], df["TS_2"])
# ax.plot(df["DATETIME_START"], df["TS_3"])

fig.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_1708\1150363855.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Select the stations that have some TS measuerments (aka, the depth metadata is not NaN)
TS_stations = meta_df[~meta_df["SOIL_TEMP_PROBE_DEPTHS"].isna()]
TS_stations
# Out:
#    SITE_ID                                          SITE_NAME  \
# 0   AT-Neu                                           Neustift
# 4   CA-SCB                                   Scotty Creek Bog
# 5   CA-SCC                             Scotty Creek Landscape
# 6   CH-Cha                                             Chamau
# 7   CH-Dav                                              Davos
# 8   CH-Oe2                                     Oensingen crop
# 11  DE-Hte                                         Huetelmoor
# 12  DE-SfN                                  Schechenfilz Nord
# 13  DE-Zrk                                           Zarnekow
# 14  FI-Hyy                                           Hyytiala
# 15  FI-Lom                                      Lompolojankka
# 16  FI-Si2                                    Siikaneva-2 Bog
# 17  FI-Sii                                          Siikaneva
# 18  FR-LGt                                          La Guette
# 20  ID-Pag                      Palangkaraya undrained forest
# 21  IT-BCi                                       Borgo Cioffi
# 22  IT-Cas                                         Castellaro
# 23  JP-BBY                                          Bibai bog
# 24  JP-Mse                              Mase rice paddy field
# 26  KR-CRK                                Cheorwon Rice paddy
# 27  MY-MLM                              Maludam National Park
# 28  NL-Hor                                        Horstermeer
# 29  NZ-Kop                                           Kopuatai
# 31  RU-Ch2                                  Chersky reference
# 32  RU-Che                                            Cherski
# 36  SE-Deg                                             Degero
# 37  SE-St1                                Stordalen grassland
# 39  US-A03                                   ARM-AMF3-Oliktok
# 40  US-A10                                     ARM-NSA-Barrow
# 44  US-Bi1                             Bouldin Island Alfalfa
# 45  US-Bi2                                Bouldin Island corn
# 46  US-BZB                      Bonanza Creek Thermokarst Bog
# 47  US-BZF                             Bonanza Creek Rich Fen
# 51  US-EDN                    Eden Landing Ecological Reserve
# 52  US-EML  Eight Mile Lake Permafrost thaw gradient, Heal...
# 53  US-Ho1                        Howland Forest (main tower)
# 56  US-ICs          Imnavait Creek Watershed Wet Sedge Tundra
# 57  US-Ivo                                             Ivotuk
# 58  US-LA1                   Pointe-aux-Chenes Brackish Marsh
# 59  US-LA2                      Salvador WMA Freshwater Marsh
# 60  US-Los                                         Lost Creek
# 63  US-Myb                                   Mayberry Wetland
# 64  US-NC4                                  NC_AlligatorRiver
# 67  US-ORv              Olentangy River Wetland Research Park
# 68  US-OWC                                    Old Woman Creek
# 70  US-Snd                                     Sherman Island
# 71  US-Sne                    Sherman Island Restored Wetland
# 73  US-StJ                                   St Jones Reserve
# 74  US-Tw1                        Twitchell Wetland West Pond
# 75  US-Tw3                                  Twitchell Alfalfa
# 76  US-Tw4                         Twitchell East End Wetland
# 77  US-Tw5                                  East Pond Wetland
# 78  US-Twt                                   Twitchell Island
# 79  US-Uaf                    University of Alaska, Fairbanks
# 80  US-WPT                           Winous Point North Marsh
#
#                                        SITE_PERSONNEL      COUNTRY        LAT  \
# 0                                     Georg Wohlfahrt      Austria  47.116670
# 4                     Oliver Sonnentag, Manuel Helbig       Canada  61.308900
# 5                     Oliver Sonnentag, Manuel Helbig       Canada  61.307900
# 6                                       Nina Buchmann  Switzerland  47.210220
# 7                                       Nina Buchmann  Switzerland  46.815330
# 8                                       Nina Buchmann  Switzerland  47.286420
# 11                                  Gerald Jurasinski      Germany  54.210278
# 12                                  Hans Peter Schmid      Germany  47.806390
# 13                                      Torsten Sachs      Germany  53.875940
# 14                       Timo Vesala, Ivan Mammarella      Finland  61.847410
# 15                                     Annalea Lohila      Finland  67.997240
# 16  Timo Vesala, Ivan Mammarella, Eeva-Stiina Tuit...      Finland  61.837200
# 17  Timo Vesala, Ivan Mammarella, Eeva-Stiina Tuit...      Finland  61.832650
# 18  Adrien Jacotot, Sébastien Gogo, Fatima Laggoun...       France  47.322917
# 20                                     Takashi Hirano    Indonesia  -2.320000
# 21                                  Vincenzo Magliulo        Italy  40.523750
# 22  Giovanni Manca, Ignacio Goded, Carsten Gruenin...        Italy  45.070047
# 23                                    Masahito Ueyama        Japan  43.323006
# 24                                       Akira Miyata        Japan  36.053930
# 26                        Youngryel Ryu, Minseok Kang        Korea  38.201300
# 27  Angela C. I. Tang, Guan Xhuan Wong, Lulie Melling     Malaysia   1.453575
# 28                                         Han Dolman  Netherlands  52.240350
# 29                                      Dave Campbell  New Zealand -37.387900
# 31                                  Matthias Goeckede       Russia  68.616890
# 32                                  Matthias Goeckede       Russia  68.613040
# 36                      Matthias Peichl, Mats Nilsson       Sweden  64.182029
# 37                     Thomas Friborg, Joachim Jansen       Sweden  68.354149
# 39        Ryan Sullivan, David Cook, David Billesbach          USA  70.495328
# 40        Ryan Sullivan, David Cook, David Billesbach          USA  71.324200
# 44                                   Dennis Baldocchi          USA  38.099154
# 45                                   Dennis Baldocchi          USA  38.109000
# 46                                 Eugenie Euskirchen          USA  64.695547
# 47                                 Eugenie Euskirchen          USA  64.703733
# 51                                       Patty Oikawa          USA  37.615620
# 52                                         Ted Schuur          USA  63.878400
# 53                 Andrew Richardson, David Hollinger          USA  45.204100
# 56                                 Eugenie Euskirchen          USA  68.605800
# 57                                     Donatella Zona          USA  68.486500
# 58                                         Ken Krauss          USA  29.501300
# 59                                         Ken Krauss          USA  29.858700
# 60                                        Ankur Desai          USA  46.082700
# 63                                   Dennis Baldocchi          USA  38.049861
# 64                                      Asko Noormets          USA  35.787900
# 67                                         Gil Bohrer          USA  40.020100
# 68                                         Gil Bohrer          USA  41.379517
# 70                                   Dennis Baldocchi          USA  38.037300
# 71                                   Dennis Baldocchi          USA  38.036900
# 73                                     Rodrigo Vargas          USA  39.088211
# 74                                   Dennis Baldocchi          USA  38.107400
# 75                                   Dennis Baldocchi          USA  38.115900
# 76                                   Dennis Baldocchi          USA  38.102744
# 77                                   Dennis Baldocchi          USA  38.107192
# 78                                   Dennis Baldocchi          USA  38.108720
# 79                                    Masahito Ueyama          USA  64.866270
# 80                            Jiquen Chen, Housen Chu          USA  41.464639
#
#            LON SITE_CLASSIFICATION       UPLAND_CLASS IGBP KOPPEN  ...  \
# 0    11.317500              Upland      Alpine meadow  GRA    Dfb  ...
# 4  -121.298400                 Bog                NaN  WET    Dfc  ...
# 5  -121.299200              Upland  Needleleaf forest  ENF    Dfc  ...
# 6     8.410440              Upland          Grassland  GRA    Cfb  ...
# 7     9.855910              Upland  Needleleaf forest  ENF     ET  ...
# 8     7.733750              Upland       Crop - wheat  CRO    Cfb  ...
# 11   12.176111                 Fen                NaN  WET    Dfb  ...
# 12   11.327500                 Bog                NaN  WET    Cfb  ...
# 13   12.889010                 Fen                NaN  WET    Dfb  ...
# 14   24.294770              Upland  Needleleaf forest  ENF    Dfc  ...
# 15   24.209180                 Fen                NaN  WET    Dfc  ...
# 16   24.196700                 Bog                NaN  WET    Dfc  ...
# 17   24.192850                 Fen                NaN  WET    Dfc  ...
# 18    2.284102                 Fen                NaN  WET    Cfb  ...
# 20  113.900000               Swamp                NaN  EBF     Af  ...
# 21   14.957440              Upland        Crop - corn  CRO    Csa  ...
# 22    8.717522                Rice                NaN  CRO    Cfa  ...
# 23  141.810697                 Bog                NaN  WET    Dfb  ...
# 24  140.026930                Rice                NaN  CRO    Cfa  ...
# 26  127.250600                Rice                NaN  CRO    Dwa  ...
# 27  111.149492               Swamp                NaN  EBF     Af  ...
# 28    5.071300             Drained          Grassland  GRA    Cfb  ...
# 29  175.553900                 Bog                NaN  EBF    Cfb  ...
# 31  161.350890          Wet tundra                NaN  WET    Dfc  ...
# 32  161.341430             Drained                NaN  WET    Dfc  ...
# 36   19.556539                 Fen                NaN  GRA    Dfc  ...
# 37   19.050333                 Fen                NaN  WET    Dfc  ...
# 39 -149.882297          Wet tundra                NaN  BSV     ET  ...
# 40 -156.614900          Wet tundra                NaN  BSV     ET  ...
# 44 -121.499330             Drained     Crop - alfalfa  CRO    Csa  ...
# 45 -121.535000             Drained        Crop - corn  CRO    Csa  ...
# 46 -148.320836                 Bog                NaN  WET    Dfd  ...
# 47 -148.313333                 Fen                NaN  WET    Dfd  ...
# 51 -122.114000          Salt marsh                NaN  WET    Csa  ...
# 52 -149.253600              Upland             Tundra  OSH     ET  ...
# 53  -68.740200              Upland  Needleleaf forest  ENF    Dfb  ...
# 56 -149.311000          Wet tundra                NaN  WET     ET  ...
# 57 -155.750300          Wet tundra                NaN  WET     ET  ...
# 58  -90.444900          Salt marsh                NaN  WET    Cfa  ...
# 59  -90.286900               Marsh                NaN  WET    Cfa  ...
# 60  -89.979200                 Fen                NaN  WET    Dfb  ...
# 63 -121.764980               Marsh                NaN  WET    Csa  ...
# 64  -75.903800               Swamp                NaN  WET    Cfa  ...
# 67  -83.018300               Marsh                NaN  WET    Cfa  ...
# 68  -82.512467               Marsh                NaN  WET    Dfb  ...
# 70 -121.753700             Drained          Grassland  GRA    Csa  ...
# 71 -121.754700               Marsh                NaN  GRA    Csa  ...
# 73  -75.437225          Salt marsh                NaN  WET    Cfa  ...
# 74 -121.646900               Marsh                NaN  WET    Csa  ...
# 75 -121.646700             Drained     Crop - alfalfa  CRO    Csa  ...
# 76 -121.641329               Marsh                NaN  WET    Csa  ...
# 77 -121.642576               Marsh                NaN  WET    Csa  ...
# 78 -121.653100                Rice                NaN  CRO    Csa  ...
# 79 -147.855530                 Bog                NaN  ENF    Dwc  ...
# 80  -82.996157               Marsh                NaN  WET    Dfa  ...
#
#    YEAR_START YEAR_END  UTC_OFFSET  \
# 0        2010     2012           1
# 4        2014     2017          -7
# 5        2013     2016          -7
# 6        2012     2016           1
# 7        2016     2017           1
# 8        2018     2018           1
# 11       2011     2018           1
# 12       2012     2014           1
# 13       2013     2018           1
# 14       2016     2016           2
# 15       2006     2010           2
# 16       2012     2016           2
# 17       2013     2018           2
# 18       2017     2018           1
# 20       2016     2017           7
# 21       2017     2018           1
# 22       2009     2010           1
# 23       2015     2018           9
# 24       2012     2012           9
# 26       2015     2018           9
# 27       2014     2015           8
# 28       2007     2009           1
# 29       2012     2015          13
# 31       2014     2016          11
# 32       2014     2016          11
# 36       2014     2018           1
# 37       2012     2014           1
# 39       2015     2018          -9
# 40       2012     2018          -9
# 44       2016     2018          -8
# 45       2017     2018          -8
# 46       2014     2016          -9
# 47       2014     2016          -9
# 51       2018     2018          -8
# 52       2015     2018          -9
# 53       2012     2018          -5
# 56       2014     2016          -9
# 57       2013     2016          -9
# 58       2011     2012          -6
# 59       2011     2013          -6
# 60       2014     2018          -6
# 63       2010     2018          -8
# 64       2012     2016          -5
# 67       2011     2015          -5
# 68       2015     2016          -5
# 70       2010     2015          -8
# 71       2016     2018          -8
# 73       2016     2016          -5
# 74       2011     2018          -8
# 75       2013     2014          -8
# 76       2013     2018          -8
# 77       2018     2018          -8
# 78       2009     2017          -8
# 79       2011     2018          -9
# 80       2011     2013          -5
#
#                                SOIL_TEMP_PROBE_DEPTHS  MOSS_BROWN  \
# 0       TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm;           0
# 4   TS_1 = 0cm; TS_2 = -0.02cm; TS_3 = -0.04cm; TS...           0
# 5   TS_1 = -0.1cm; TS_2 = -0.15cm; TS_3 = -0.2cm; ...           0
# 6   TS_1 = -0.01cm; TS_2 = -0.02cm; TS_3 = -0.04cm...           0
# 7      TS_1 = -0.05cm; TS_2 = -0.15cm; TS_3 = -0.5cm;           1
# 8   TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.15cm;...           0
# 11          TS_1 = 0cm; TS_2 = -0.1cm; TS_3 = -0.2cm;           0
# 12  TS_1 = -0.02cm; TS_3 = -0.1cm; TS_4 = -0.2cm; ...           0
# 13  TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm; ...           0
# 14  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.12cm...           1
# 15      TS_1 = -0.07cm; TS_2 = -0.3cm; TS_3 = -0.5cm;           1
# 16  TS_1 = -0.05cm; TS_2 = -0.2cm; TS_3 = -0.35cm;...           0
# 17  before 2016(TS_1 = -0.05cm; TS_2 = -0.2cm; TS_...           0
# 18  TS_1 = -0.02cm; TS_2 = -0.05cm; TS_3 = -0.1cm;...           0
# 20                                    TS_1 = -0.05cm;           0
# 21  TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.3cm; ...           0
# 22      TS_1 = -0.05cm; TS_2 = -0.3cm; TS_3 = -0.5cm;           0
# 23  TS_1 = -0.183cm; TS_2 = -0.233cm; TS_3 = -0.28...           0
# 24  TS_1 = -0.01cm; TS_2 = -0.025cm; TS_3 = -0.05c...           0
# 26                    TS_1 = -0.05cm; TS_2 = -0.15cm;           0
# 27                                    TS_1 = -0.05cm;           0
# 28  TS_1 = -0.01cm; TS_2 = -0.02cm; TS_3 = -0.04cm...           0
# 29       TS_1 = -0.5cm; TS_2 = -0.1cm; TS_3 = -0.2cm;           0
# 31    TS_1 = -0.04cm; TS_2 = -0.08cm; TS_3 = -0.16cm;           0
# 32    TS_1 = -0.04cm; TS_2 = -0.08cm; TS_3 = -0.16cm;           0
# 36  TS_1 = -0.02cm; TS_2 = -0.05cm; TS_3 = -0.1cm;...           0
# 37  TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.25cm;...           1
# 39     TS_1 = -0.025cm; TS_2 = -0.1cm; TS_3 = -0.3cm;           0
# 40     TS_1 = -0.025cm; TS_2 = -0.1cm; TS_3 = -0.3cm;           0
# 44  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 45  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 46                   TS_1 = -0.075cm; TS_2 = -0.05cm;           0
# 47                   TS_1 = -0.075cm; TS_2 = -0.05cm;           1
# 51  TS_1 = -0.25cm; TS_2 = -0.15cm; TS_3 = -0.05cm...           0
# 52  TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm; ...           1
# 53                     TS_1 = -0.05cm; TS_2 = -0.1cm;           0
# 56                   TS_1 = -0.075cm; TS_2 = -0.05cm;           0
# 57  TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.15cm;...           1
# 58                                      TS  = -0.1cm;           0
# 59                                       TS = -0.1cm;           0
# 60  TS_1 = 0cm; TS_2 = -0.05cm; TS_3 = -0.1cm; TS_...           0
# 63  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 64                     TS_1 = -0.05cm; TS_2 = -0.2cm;           0
# 67                                    TS_1 = -0.08cm;           0
# 68                     TS_1 = -0.05cm; TS_2 = -0.3cm;           0
# 70  TS_1 = -0.08cm; TS_2 = -0.16cm; TS_3 = nancm; ...           0
# 71  TS_1 = -0.01cm; TS_2 = -0.02cm; TS_3 = -0.08cm...           0
# 73                     TS_2 = -0.05cm; TS_3 = -0.1cm;           0
# 74  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 75  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 76  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 77  TS_1 = -0.02cm; TS_2 = -0.1cm; TS_3 = -0.02cm;...           0
# 78  TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm...           0
# 79  TS_1 = -0.09cm; TS_2 = -0.183cm; TS_3 = -0.283...           1
# 80                      TS_1 = -0.1cm; TS_2 = -0.3cm;           0
#
#    MOSS_SPHAGNUM  AERENCHYMATOUS  ERI_SHRUB  TREE         DOM_VEG
# 0              0               1          0     0  aerenchymatous
# 4              1               1          1     0   moss_sphagnum
# 5              1               0          1     1            tree
# 6              0               1          0     0  aerenchymatous
# 7              0               0          1     1            tree
# 8              0               1          0     0  aerenchymatous
# 11             0               1          0     0  aerenchymatous
# 12             1               1          1     1            tree
# 13             0               1          0     0  aerenchymatous
# 14             1               0          1     1            tree
# 15             1               1          1     0  aerenchymatous
# 16             1               1          1     1   moss_sphagnum
# 17             1               1          0     0   moss_sphagnum
# 18             1               1          1     0  aerenchymatous
# 20             0               1          0     1            tree
# 21             0               1          0     0  aerenchymatous
# 22             0               1          0     0  aerenchymatous
# 23             1               1          1     0  aerenchymatous
# 24             0               1          0     0  aerenchymatous
# 26             0               1          0     0  aerenchymatous
# 27             0               0          0     1            tree
# 28             0               1          0     0  aerenchymatous
# 29             1               1          0     0  aerenchymatous
# 31             0               1          1     0  aerenchymatous
# 32             0               1          1     0  aerenchymatous
# 36             1               1          1     0   moss_sphagnum
# 37             1               1          1     0  aerenchymatous
# 39             1               1          0     0   moss_sphagnum
# 40             1               1          0     0   moss_sphagnum
# 44             0               1          0     0  aerenchymatous
# 45             0               1          0     0  aerenchymatous
# 46             1               1          1     0       eri_shrub
# 47             1               1          0     0  aerenchymatous
# 51             0               1          0     0  aerenchymatous
# 52             0               1          1     0  aerenchymatous
# 53             0               0          0     1            tree
# 56             0               1          1     0  aerenchymatous
# 57             0               1          1     0  aerenchymatous
# 58             0               1          0     0  aerenchymatous
# 59             0               1          0     0  aerenchymatous
# 60             0               1          1     1       eri_shrub
# 63             0               1          0     0  aerenchymatous
# 64             0               1          0     1  aerenchymatous
# 67             0               1          0     0  aerenchymatous
# 68             0               1          0     0  aerenchymatous
# 70             0               1          0     0  aerenchymatous
# 71             0               1          0     0  aerenchymatous
# 73             0               1          0     0  aerenchymatous
# 74             0               1          0     0  aerenchymatous
# 75             0               1          0     0  aerenchymatous
# 76             0               1          0     0  aerenchymatous
# 77             0               1          0     0  aerenchymatous
# 78             0               1          0     0  aerenchymatous
# 79             1               1          1     1   moss_sphagnum
# 80             0               1          0     0  aerenchymatous
#
# [55 rows x 22 columns]

# %%
# Plot the locations into a wolrdmap:

lat, lon = TS_stations["LAT"], TS_stations["LON"]

# %%
import cartopy.crs as ccrs

# plot available station on a map
fig, ax = plt.subplots(
    1, 1, figsize=(12, 8), subplot_kw={"projection": ccrs.PlateCarree()}
)

ax.scatter(lon, lat, transform=ccrs.PlateCarree(), color="red", marker="o", s=20)

# Add coastlines for better visualization
ax.coastlines()

plt.show()

fig.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_1708\476492496.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# METADATA FLAGS related to vegetation:
# https://fluxnet.org/data/fluxnet-ch4-community-product/

""" 
MOSS_BROWN: presence or absence (1 or 0) of brown mosses on the site
MOSS_SPHAGNUM: presence or absence (1 or 0) of Sphagnum mosses on the site
AERENCHYMATOUS: presence or absence (1 or 0) of species that have aerenchyma (mostly Order Poales but includes exceptions)
ERI_SHRUB: presence or absence (1 or 0) of ericaceous shrubs on the site
TREE: presence or absence (1 or 0) of trees (of any height) on the site

DOM_VEG: Dominant plant functional type in the tower footprint. Lead site investigators had to pick one from the following options: moss_brown, moss_sphagnum, aerenchymatous, eri_shrub or tree
"""

TS_stations.columns
# Out:
# Index(['SITE_ID', 'SITE_NAME', 'SITE_PERSONNEL', 'COUNTRY', 'LAT', 'LON',
#        'SITE_CLASSIFICATION', 'UPLAND_CLASS', 'IGBP', 'KOPPEN',
#        'ORIGINAL_DATA_SOURCE', 'FLUXNET-CH4_DATA_POLICY', 'YEAR_START',
#        'YEAR_END', 'UTC_OFFSET', 'SOIL_TEMP_PROBE_DEPTHS', 'MOSS_BROWN',
#        'MOSS_SPHAGNUM', 'AERENCHYMATOUS', 'ERI_SHRUB', 'TREE', 'DOM_VEG'],
#       dtype='object')

# %%
# [print(v) for v in TS_stations["SOIL_TEMP_PROBE_DEPTHS"]]; # Not recommended ...
for v in TS_stations["SOIL_TEMP_PROBE_DEPTHS"]:
    print(v)
# Out:
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm;
# TS_1 = 0cm; TS_2 = -0.02cm; TS_3 = -0.04cm; TS_4 = -0.08cm; TS_5 = -0.16cm; TS_6 = -0.32cm; TS_7 = -0.64cm ;TS_8 = -1.28cm;
# TS_1 = -0.1cm; TS_2 = -0.15cm; TS_3 = -0.2cm; TS_4 = -0.25cm; TS_5 = -0.3cm; TS_6 = -0.5cm; TS_7 = -0.6cm; TS_8 = -0.7cm;
# TS_1 = -0.01cm; TS_2 = -0.02cm; TS_3 = -0.04cm; TS_4 = -0.07cm; TS_5 = -0.1cm; TS_6 = -0.15cm; TS_7 = -0.25cm; TS_8 = -0.4cm; TS_9 = -0.95cm;
# TS_1 = -0.05cm; TS_2 = -0.15cm; TS_3 = -0.5cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.15cm;  TS_5 = -0.3cm; TS_6 = -0.5cm;
# TS_1 = 0cm; TS_2 = -0.1cm; TS_3 = -0.2cm;
# TS_1 = -0.02cm; TS_3 = -0.1cm; TS_4 = -0.2cm; TS_5 = -0.5cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm; TS_4 = -0.3cm; TS_5 = -0.5cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.12cm; TS_4 = -0.25cm; TS_5 = -0.5cm;
# TS_1 = -0.07cm; TS_2 = -0.3cm; TS_3 = -0.5cm;
# TS_1 = -0.05cm; TS_2 = -0.2cm; TS_3 = -0.35cm; TS_4 = -0.5cm;    TS_1 = -0.05cm; TS_2 = -0.2cm; TS_3 = -0.35cm; TS_4 = -0.5cm;
# before 2016(TS_1 = -0.05cm; TS_2 = -0.2cm; TS_3 = -0.35cm; TS_4 = -0.5cm;    TS_2 = -0.2cm; TS_3 = -0.35cm; TS_4 = -0.5cm) after 2017 (TS_1 = 0cm; TS_2 = -0.5cm; TS_3 = -0.1cm; TS_4 = -0.15cm; TS_5 = -0.25cm; TS_6 = -0.45cm; TS_7 = -0.95cm)
# TS_1 = -0.02cm; TS_2 = -0.05cm; TS_3 = -0.1cm; TS_4 = -0.2cm; TS_5 = -0.4cm;
# TS_1 = -0.05cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.3cm; TS_4 = -0.5cm; TS_5 = -1cm;
# TS_1 = -0.05cm; TS_2 = -0.3cm; TS_3 = -0.5cm;
# TS_1 = -0.183cm; TS_2 = -0.233cm; TS_3 = -0.283cm; TS_4 = -0.383cm; TS_5 = -0.483cm;
# TS_1 = -0.01cm; TS_2 = -0.025cm; TS_3 = -0.05cm; TS_4 = -0.1cm; TS_5 = -0.2cm; TS_6 = -0.4cm;
# TS_1 = -0.05cm; TS_2 = -0.15cm;
# TS_1 = -0.05cm;
# TS_1 = -0.01cm; TS_2 = -0.02cm; TS_3 = -0.04cm; TS_4 = -0.05cm; TS_5 = -0.1cm; TS_6 = -0.15cm; TS_7 = -0.25cm; TS_8 = -0.4cm; TS_9 = -0.6cm;
# TS_1 = -0.5cm; TS_2 = -0.1cm; TS_3 = -0.2cm;
# TS_1 = -0.04cm; TS_2 = -0.08cm; TS_3 = -0.16cm;
# TS_1 = -0.04cm; TS_2 = -0.08cm; TS_3 = -0.16cm;
# TS_1 = -0.02cm; TS_2 = -0.05cm; TS_3 = -0.1cm; TS_4 = -0.15cm; TS_5 = -0.3cm; TS_6 = -0.5cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.25cm; TS_4 = -0.5cm;
# TS_1 = -0.025cm; TS_2 = -0.1cm; TS_3 = -0.3cm;
# TS_1 = -0.025cm; TS_2 = -0.1cm; TS_3 = -0.3cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.075cm; TS_2 = -0.05cm;
# TS_1 = -0.075cm; TS_2 = -0.05cm;
# TS_1 = -0.25cm; TS_2 = -0.15cm; TS_3 = -0.05cm; TS_4 = 0cm; TS_5 = 0.05cm; TS_6 = 0.1cm; TS_7 = 0.2cm; TS_8 = 0.3cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.2cm; TS_4 = -0.4cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm;
# TS_1 = -0.075cm; TS_2 = -0.05cm;
# TS_1 = -0.05cm; TS_2 = -0.1cm; TS_3 = -0.15cm; TS_4 = -0.3cm; TS_5 = -0.4cm;
# TS  = -0.1cm;
# TS = -0.1cm;
# TS_1 = 0cm; TS_2 = -0.05cm; TS_3 = -0.1cm; TS_4 = -0.2cm; TS_5 = -0.5cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.05cm; TS_2 = -0.2cm;
# TS_1 = -0.08cm;
# TS_1 = -0.05cm; TS_2 = -0.3cm;
# TS_1 = -0.08cm; TS_2 = -0.16cm; TS_3 = nancm; TS_4 = nancm; TS_5 = nancm; TS_6 = nancm;
# TS_1 = -0.01cm; TS_2 = -0.02cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_2 = -0.05cm; TS_3 = -0.1cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.02cm; TS_2 = -0.1cm; TS_3 = -0.02cm; TS_4 = -0.08cm; TS_5 = -0.16cm;
# TS_1 = -0.02cm; TS_2 = -0.04cm; TS_3 = -0.08cm; TS_4 = -0.16cm; TS_5 = -0.32cm;
# TS_1 = -0.09cm; TS_2 = -0.183cm; TS_3 = -0.283cm; TS_4 = -0.367cm; TS_5 = -0.5cm; TS_6 = -0.6cm; TS_7 = -0.75cm; TS_8 = -0.925cm; TS_9 = -1cm;
# TS_1 = -0.1cm; TS_2 = -0.3cm;

# %%
meta_df.loc[2]
# Out:
# SITE_ID                            BW-Gum
# SITE_NAME                            Guma
# SITE_PERSONNEL             Carole Helfter
# COUNTRY                          Botswana
# LAT                            -18.964722
# LON                             22.371111
# SITE_CLASSIFICATION                 Swamp
# UPLAND_CLASS                          NaN
# IGBP                                  WET
# KOPPEN                                Bsh
# ORIGINAL_DATA_SOURCE             EuroFlux
# FLUXNET-CH4_DATA_POLICY           CCBY4.0
# YEAR_START                           2018
# YEAR_END                             2018
# UTC_OFFSET                              2
# SOIL_TEMP_PROBE_DEPTHS                NaN
# MOSS_BROWN                              0
# MOSS_SPHAGNUM                           0
# AERENCHYMATOUS                          1
# ERI_SHRUB                               0
# TREE                                    1
# DOM_VEG                    aerenchymatous
# Name: 2, dtype: object
