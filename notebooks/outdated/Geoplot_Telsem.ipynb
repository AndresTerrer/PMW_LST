# %%
import geopandas as gp
import geoplot

# %%
gdf = gp.read_file("..\data\output\GeoTelsem\ssmi_mean_emis_climato_01_cov_interpol_M2.geojson")

# %%
geoplot.pointplot(gdf, projection=geoplot.PlateCarree(), s=0.1)
# Out:
# <GeoAxes: >

# %%
geoplot.pointplot(gdf, projection=geoplot.crs.AzimuthalEquidistant(central_latitude=90), s=0.2, figsize = (10,10))
# Out:
# <GeoAxes: >

# %%
geoplot.pointplot(gdf, projection=geoplot.crs.NorthPolarStereo(), s=0.2, figsize = (10,10))
# Out:
# <GeoAxes: >
